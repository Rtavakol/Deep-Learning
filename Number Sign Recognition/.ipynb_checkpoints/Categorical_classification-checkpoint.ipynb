# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
x_l = np.load('X.npy')
Y_l = np.load('Y.npy')

# %%
# %matplotlib notebook
img_size = 64
plt.subplot(1, 2, 1)
plt.imshow(x_l[0,:, :].reshape(img_size, img_size))
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(x_l[900].reshape(img_size, img_size))
plt.axis('off')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# (-0.5, 63.5, 63.5, -0.5)

# %%
X = x_l
Y = Y_l
print(x_l.shape)
print(Y_l.shape)
# Out:
# (2062, 64, 64)
# (2062, 10)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.15, random_state = 42)
print(X_train.shape[0])
print(X_test.shape[0])
# Out:
# 1752
# 310

# %%
X_train_flatten = X_train.reshape(X_train.shape[0], X_train.shape[1] * X_train.shape[2])
X_test_flatten = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2])
print(X_train_flatten.shape)
print(X_test_flatten.shape)
# Out:
# (1752, 4096)
# (310, 4096)

# %%
x_train = X_train_flatten.T
x_test = X_test_flatten.T
y_test = Y_test.T
y_train = Y_train.T
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4096, 1752)
# (4096, 310)
# (10, 1752)
# (10, 310)

# %%
col_index = {0: 9, 1:0, 2:7, 3:6, 4:1, 5:8, 6:4, 7:3, 8:2, 9:5}
plt.figure(figsize=(8, 8))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(X_train[i].reshape(img_size, img_size))
    plt.title('Number: {}'.format(col_index[Y_train[i].argmax()]), fontsize = 8)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">

# %% [markdown]
# # Implementing with Keras Libraries

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential 
from keras.layers import Dense, Flatten

# %%
x_train, y_train, x_test, y_test = x_train.T, y_train.T, x_test.T, y_test.T
model = Sequential() # initialize neural network
model.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu', input_dim = x_train.shape[1]))
model.add(Dense(units = 20, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 10, kernel_initializer = 'uniform', activation = 'softmax'))
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.fit(x_train, y_train, epochs = 200)
# Out:
# Epoch 1/200
# 1752/1752 [==============================] - 1s 430us/step - loss: 2.3065 - accuracy: 0.0850
# Epoch 2/200
# 1752/1752 [==============================] - 1s 341us/step - loss: 2.2996 - accuracy: 0.1022
# Epoch 3/200
# 1752/1752 [==============================] - 1s 339us/step - loss: 2.2796 - accuracy: 0.1450
# Epoch 4/200
# 1752/1752 [==============================] - 1s 338us/step - loss: 2.2112 - accuracy: 0.1792
# Epoch 5/200
# 1752/1752 [==============================] - 1s 340us/step - loss: 2.1251 - accuracy: 0.1981
# Epoch 6/200
# 1752/1752 [==============================] - 1s 342us/step - loss: 2.0536 - accuracy: 0.2432
# Epoch 7/200
# 1752/1752 [==============================] - 1s 341us/step - loss: 2.0184 - accuracy: 0.2580
# Epoch 8/200
# 1752/1752 [==============================] - 1s 341us/step - loss: 1.9383 - accuracy: 0.3025
# Epoch 9/200
# 1752/1752 [==============================] - 1s 339us/step - loss: 1.8858 - accuracy: 0.3008
# Epoch 10/200
# ...

# %%
x_train.shape[1]
# Out:
# 4096

# %%
y_prediction = np.zeros((x_test.shape[0], 1)) # or np.zeros(y_test.shape)
prediction = model.predict(x_test)
for i in range(model.predict(x_test).shape[0]):
    if prediction[i, 0] <= 0.5:
        prediction[i, 0] = 0
    if prediction[i, 0] > 0.5:
        prediction[i, 0] = 1

# %%
print('Accuracy on test data')
print(model.evaluate(x_test, y_test)[1])
# Out:
# Accuracy on test data
# 310/310 [==============================] - 0s 216us/step
# 0.7419354915618896

# %%
(100 - 100 * np.mean(np.abs(y_test - prediction)))
# Out:
# 93.26440208612341

# %%
# %matplotlib notebook
plt.figure(figsize = (8, 8))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(x_test[i].reshape(img_size, img_size))
    if col_index[y_test[i].argmax()] == col_index[prediction[i].argmax()]:
        color = 'k'
    else:
        color = 'r'
        
    plt.title("Label: {}".format(col_index[y_test[i].argmax()]) + '\n' + 
              'Predicted label: {}'.format(col_index[prediction[i].argmax()]), color = color)
    
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">

# %%
# The model is not optimized yet. One can do experiment to find the optimum value for 
# numbers of layers,
# number of nodes,
# dropout,
# pooling,
# learning rate, 
# ...
