# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
x_l = np.load('X.npy')
Y_l = np.load('Y.npy')

# %%
# %matplotlib notebook
img_size = 64
plt.subplot(1, 2, 1)
plt.imshow(x_l[0,:, :].reshape(img_size, img_size))
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(x_l[900].reshape(img_size, img_size))
plt.axis('off')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# (-0.5, 63.5, 63.5, -0.5)

# %%
X = x_l
Y = Y_l
print(x_l.shape)
print(Y_l.shape)
# Out:
# (2062, 64, 64)
# (2062, 10)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.15, random_state = 42)
print(X_train.shape[0])
print(X_test.shape[0])
# Out:
# 1752
# 310

# %%
X_train_flatten = X_train.reshape(X_train.shape[0], X_train.shape[1] * X_train.shape[2])
X_test_flatten = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2])
print(X_train_flatten.shape)
print(X_test_flatten.shape)
# Out:
# (1752, 4096)
# (310, 4096)

# %%
x_train = X_train_flatten.T
x_test = X_test_flatten.T
y_test = Y_test.T
y_train = Y_train.T
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4096, 1752)
# (4096, 310)
# (10, 1752)
# (10, 310)

# %%
col_index = {0: 9, 1:0, 2:7, 3:6, 4:1, 5:8, 6:4, 7:3, 8:2, 9:5}
plt.figure(figsize=(8, 8))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(X_train[i].reshape(img_size, img_size))
    plt.title('Number: {}'.format(col_index[Y_train[i].argmax()]), fontsize = 8)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">

# %% [markdown]
# # Implementing with Keras Libraries

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential 
from keras.layers import Dense, Flatten
# Out:
# Using TensorFlow backend.

# %%
x_train, y_train, x_test, y_test = x_train.T, y_train.T, x_test.T, y_test.T
model = Sequential() # initialize neural network
model.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu', input_dim = x_train.shape[1]))
#model.add(Dense(units = 20, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 10, kernel_initializer = 'uniform', activation = 'softmax'))
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.fit(x_train, y_train, epochs = 100)
# Out:
# WARNING:tensorflow:From C:\Users\u0125384\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# 1752/1752 [==============================] - 1s 402us/step - loss: 2.3435 - accuracy: 0.0993
# Epoch 2/100
# 1752/1752 [==============================] - 1s 333us/step - loss: 2.3009 - accuracy: 0.1056
# Epoch 3/100
# 1752/1752 [==============================] - 1s 332us/step - loss: 2.3027 - accuracy: 0.0908
# Epoch 4/100
# 1752/1752 [==============================] - 1s 334us/step - loss: 2.3027 - accuracy: 0.0959
# Epoch 5/100
# 1752/1752 [==============================] - 1s 332us/step - loss: 2.3026 - accuracy: 0.0879
# Epoch 6/100
# 1752/1752 [==============================] - 1s 313us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 85/100
# 1752/1752 [==============================] - 1s 311us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 86/100
# 1752/1752 [==============================] - 1s 311us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 87/100
# 1752/1752 [==============================] - 1s 317us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 88/100
# 1752/1752 [==============================] - 1s 309us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 89/100
# 1752/1752 [==============================] - 1s 310us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 90/100
# 1752/1752 [==============================] - 1s 313us/step - loss: 2.3024 - accuracy: 0.10390s - loss: 2.3034 - ac
# Epoch 91/100
# 1752/1752 [==============================] - 1s 313us/step - loss: 2.3025 - accuracy: 0.1039
# Epoch 92/100
# 1752/1752 [==============================] - 1s 312us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 93/100
# 1752/1752 [==============================] - 1s 316us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 94/100
# 1752/1752 [==============================] - 1s 314us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 95/100
# 1752/1752 [==============================] - 1s 312us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 96/100
# 1752/1752 [==============================] - 1s 312us/step - loss: 2.3023 - accuracy: 0.1039
# Epoch 97/100
# 1752/1752 [==============================] - 1s 310us/step - loss: 2.3023 - accuracy: 0.1039
# Epoch 98/100
# 1752/1752 [==============================] - 1s 310us/step - loss: 2.3025 - accuracy: 0.1039
# Epoch 99/100
# 1752/1752 [==============================] - 1s 312us/step - loss: 2.3024 - accuracy: 0.1039
# Epoch 100/100
# 1752/1752 [==============================] - 1s 312us/step - loss: 2.3023 - accuracy: 0.1039

# %%
x_train.shape[1]
# Out:
# 4096

# %%
y_prediction = np.zeros((x_test.shape[0], 1)) # or np.zeros(y_test.shape)
prediction = model.predict(x_test)
for i in range(model.predict(x_test).shape[0]):
    if prediction[i, 0] <= 0.5:
        prediction[i, 0] = 0
    if prediction[i, 0] > 0.5:
        prediction[i, 0] = 1

# %%
print('Accuracy on test data')
print(model.evaluate(x_test, y_test)[1])
# Out:
# Accuracy on test data
# 310/310 [==============================] - 0s 165us/step
# 0.07741935551166534

# %%
(100 - 100 * np.mean(np.abs(y_test - prediction)))
# Out:
# 82.82479900818679

# %%
# %matplotlib notebook
plt.figure(figsize = (8, 8))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(x_test[i].reshape(img_size, img_size))
    plt.title("Label: {}".format(col_index[y_test[i].argmax()]) + '\n' + 
              'Predicted label: {}'.format(col_index[prediction[i].argmax()]))
    
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.3333333333334">
