# %%
# Tutorial address:
# I modified what I learnt from the link below to implement categorical classification
# https://www.kaggle.com/kanncaa1/deep-learning-tutorial-for-beginners

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from subprocess import check_output
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
print(check_output)
# Out:
# <function check_output at 0x10467c620>

# %%
x_l = np.load('X.npy')
Y_l = np.load('Y.npy')

# %%
# %matplotlib notebook
img_size = 64
plt.subplot(1, 2, 1)
plt.imshow(x_l[0,:, :].reshape(img_size, img_size))
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(x_l[900].reshape(img_size, img_size))
plt.axis('off')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-0.5, 63.5, 63.5, -0.5)

# %%
X = x_l
Y = Y_l
print(x_l.shape)
print(Y_l.shape)
# Out:
# (2062, 64, 64)
# (2062, 10)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.15, random_state = 42)
print(X_train.shape[0])
print(X_test.shape[0])
# Out:
# 1752
# 310

# %%
X_train_flatten = X_train.reshape(X_train.shape[0], X_train.shape[1] * X_train.shape[2])
X_test_flatten = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2])
print(X_train_flatten.shape)
print(X_test_flatten.shape)
# Out:
# (1752, 4096)
# (310, 4096)

# %%
x_train = X_train_flatten.T
x_test = X_test_flatten.T
y_test = Y_test.T
y_train = Y_train.T
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4096, 1752)
# (4096, 310)
# (10, 1752)
# (10, 310)

# %%
col_index = {0: 9, 1:0, 2:7, 3:6, 4:1, 5:8, 6:4, 7:3, 8:2, 9:5}
plt.figure(figsize=(8, 8))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(X_train[i].reshape(img_size, img_size))
    plt.title('Number: {}'.format(col_index[Y_train[i].argmax()]), fontsize = 8)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Implementing with Keras Libraries

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential 
from keras.layers import Dense, Flatten
# Out:
# Using Theano backend.
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'

# %%
x_train, y_train, x_test, y_test = x_train.T, y_train.T, x_test.T, y_test.T
model = Sequential() # initialize neural network
model.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu', input_dim = x_train.shape[1]))
#model.add(Dense(units = 20, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 10, kernel_initializer = 'uniform', activation = 'softmax'))
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'
# 1752/1752 [==============================] - 2s 858us/step - loss: 0.4042 - acc: 0.8756
# Epoch 84/100
# 1752/1752 [==============================] - 1s 836us/step - loss: 0.4041 - acc: 0.8779
# Epoch 85/100
# 1752/1752 [==============================] - 1s 841us/step - loss: 0.3890 - acc: 0.8813
# Epoch 86/100
# 1752/1752 [==============================] - 1s 840us/step - loss: 0.4317 - acc: 0.8596
# Epoch 87/100
# 1752/1752 [==============================] - 2s 859us/step - loss: 0.3893 - acc: 0.8830
# Epoch 88/100
# 1752/1752 [==============================] - 2s 878us/step - loss: 0.3988 - acc: 0.8676
# Epoch 89/100
# 1752/1752 [==============================] - 2s 962us/step - loss: 0.4107 - acc: 0.8739
# Epoch 90/100
# 1752/1752 [==============================] - 2s 1ms/step - loss: 0.4152 - acc: 0.8590
# Epoch 91/100
# 1752/1752 [==============================] - 2s 879us/step - loss: 0.4001 - acc: 0.8687
# Epoch 92/100
# 1752/1752 [==============================] - 2s 902us/step - loss: 0.3463 - acc: 0.8916
# Epoch 93/100
# 1752/1752 [==============================] - 2s 862us/step - loss: 0.3591 - acc: 0.8916
# Epoch 94/100
# 1752/1752 [==============================] - 2s 868us/step - loss: 0.3981 - acc: 0.8744
# Epoch 95/100
# 1752/1752 [==============================] - 2s 857us/step - loss: 0.3651 - acc: 0.8893
# Epoch 96/100
# 1752/1752 [==============================] - 2s 859us/step - loss: 0.3638 - acc: 0.8796
# Epoch 97/100
# 1752/1752 [==============================] - 2s 867us/step - loss: 0.4003 - acc: 0.8693
# Epoch 98/100
# 1752/1752 [==============================] - 2s 876us/step - loss: 0.3520 - acc: 0.8893
# Epoch 99/100
# 1752/1752 [==============================] - 2s 866us/step - loss: 0.3693 - acc: 0.8807
# Epoch 100/100
# 1752/1752 [==============================] - 2s 1ms/step - loss: 0.3580 - acc: 0.8916

# %%
x_train.shape[1]
# Out:
# 4096

# %%
y_prediction = np.zeros((x_test.shape[0], 1)) # or np.zeros(y_test.shape)
prediction = model.predict(x_test)
for i in range(model.predict(x_test).shape[0]):
    if prediction[i, 0] <= 0.5:
        prediction[i, 0] = 0
    if prediction[i, 0] > 0.5:
        prediction[i, 0] = 1

# %%
print('Accuracy on test data')
print(model.evaluate(x_test, y_test)[1])
# Out:
# Accuracy on test data
# 310/310 [==============================] - 0s 37us/step
# 0.7870967761162788

# %%
(100 - 100 * np.mean(np.abs(y_test - prediction)))
# Out:
# 94.05697454219053

# %%
# %matplotlib notebook
plt.figure(figsize = (8, 8))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(x_test[i].reshape(img_size, img_size))
    plt.title("Label: {}".format(col_index[y_test[i].argmax()]) + '\n' + 
              'Predicted label: {}'.format(col_index[prediction[i].argmax()]))
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">
